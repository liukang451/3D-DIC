# %%
import mat73
import numpy as np
import pandas as pd
#from rigid_transform_3D import rigid_transform_3D

# %%
data_dict = mat73.loadmat('sample.mat')

# %%
data_dict.keys()
# Out:
# dict_keys(['DIC3DPPresults'])

# %%
data_dict['DIC3DPPresults'].keys()
# Out:
# dict_keys(['AllPairsResults', 'DIC2Dinfo', 'Deform', 'Deform_ARBM', 'Disp', 'FaceCentroids', 'FaceCentroids_ARBM', 'FaceColors', 'FaceCorrComb', 'FaceIsoInd', 'FacePairInds', 'Faces', 'PointPairInds', 'Points3D', 'Points3D_ARBM', 'RBM', 'calibration', 'corrComb', 'distortion', 'pairIndices'])

# %%
data_dict['DIC3DPPresults']['Faces'].shape
# Out:
# (13368, 3)

# %%
facesPy = data_dict['DIC3DPPresults']['Faces']

# %%
facesPy.shape
# Out:
# (13368, 3)

# %%
facesPy[1]
# an array with float numbers, int needed
# Out:
# array([4958., 4957., 4689.])

# %%
facesPyInt = facesPy.astype(int)
facesPyInt[1]
# got int array
# Out:
# array([4958, 4957, 4689])

# %%
#sync load file
DIC3D = data_dict['DIC3DPPresults']
#[todo] save results

# %%
#get number of images
nImages = len(DIC3D['Points3D']) # DIC3D['Points3D'] is a list
nImages
# Out:
# 5

# %%
#DIC3D['Points3D'] is a list of 5 arrays
#DIC3D['Points3D'][0] is a list of 1 array, stand for a image
#DIC3D['Points3D'][0][0] is a list sized 6978 in this case
len(DIC3D['Points3D'][0][0])
# Out:
# 6978

# %%
#pre-allocate 3D-DIC result variables
Points3D_ARBM=[]
Disp_DispVec=[]
Disp_DispMgn=[]
Disp_DispVec_ARBM=[]
Disp_DispMgn_ARBM=[]
FaceCentroids=[]
FaceCentroids_ARBM=[]
FaceCorrComb=[]
FaceIsoInd=[]
RBM_RotMat=[]
RBM_TransVec=[]

# %%
def rigid_transform_3D(argA, argB):
    orgA = argA# backup for data after transformation
    nanIndexa = np.argwhere(np.isnan(argA))[:,0]
    nanIndexb = np.argwhere(np.isnan(argB))[:,0]
    nanIndexab = np.concatenate([nanIndexa,nanIndexb])
    argA = np.delete(argA, nanIndexab,0)
    argB = np.delete(argB, nanIndexab,0)
    argA = argA.transpose()  
    argB = argB.transpose()
    A = np.asmatrix(argA)
    B = np.asmatrix(argB)#as required by external file
    
    # find mean column wise different approach between matlab script
    centroid_A = np.mean(A, axis=1)
    centroid_B = np.mean(B, axis=1)

    # ensure centroids are 3x1 (necessary when A or B are
    # numpy arrays instead of numpy matrices)
    centroid_A = centroid_A.reshape(-1, 1)
    centroid_B = centroid_B.reshape(-1, 1)

    # subtract mean
    Am = A - centroid_A
    Bm = B - centroid_B

    H = np.dot(Bm,np.transpose(Am))

    # find rotation
    U, S, Vt = np.linalg.svd(H)
    S_mat = [[1,0,0],[0,1,0],[0,0,np.linalg.det(U*Vt)]]
    R = Vt.T * U.T * S_mat
    R = R.T

    t = -R*centroid_A + centroid_B
    P = ((orgA * R.T).T+t).T

    return R, t, P

# %%
#iface in range
facesPy.shape[0]
# Out:
# 13368

# %%
#Calculating displacements and rigid body motion
FaceCorrComb=[] #init, or it will append with no limit
FaceCentroids=[None]*nImages # declare it with size
Disp_DispVec=[]
Disp_DispMgn=[]
RBM_RotMat=[]
RBM_TransVec=[]
Points3D_ARBM=[]
Disp_DispVec_ARBM=[]
Disp_DispMgn_ARBM=[]
FaceCentroids_ARBM=[None]*nImages

for image in range(nImages):
    #Face correlation coefficient (worst)
    FaceCorrComb.append(np.amax(DIC3D['corrComb'][image][0][facesPyInt-1],1))# find max in each row
    #Compute face centroids
    means = []
    for ifaces in range(facesPy.shape[0]):# in shorted version will be 10, full will be 13368  
        meanOfEachLine = data_dict['DIC3DPPresults']['Points3D'][image][0][facesPyInt[ifaces,:]-1].mean(axis = 0)
        means.append(meanOfEachLine)
        FaceCentroids[image] = means
    #Compute displacements between frames (per point)
    DispVec = data_dict['DIC3DPPresults']['Points3D'][image][0] - data_dict['DIC3DPPresults']['Points3D'][0][0]
    Disp_DispVec.append(DispVec)
    Disp_DispMgn.append(np.sqrt(DispVec[:,0]**2 + DispVec[:,1]**2 + DispVec[:,2]**2))
    
    #Compute rigid body transformation between point clouds
    refP= data_dict['DIC3DPPresults']['Points3D'][image][0]
    truP = data_dict['DIC3DPPresults']['Points3D'][0][0]  
    RotMat,TransVec,P = rigid_transform_3D(refP,truP)
    RBM_RotMat.append(np.asarray(RotMat))
    RBM_TransVec.append(np.asarray(TransVec))
    Points3D_ARBM.append(np.asarray(P))
    
    #Compute displacements between sets - after RBM
    DispVecARBM = Points3D_ARBM[image] - Points3D_ARBM[0]
    #DispVecARBM = np.asarray(DispVecARBM)## check data type, matrix can not be used for **2 directly
    Disp_DispVec_ARBM.append(DispVecARBM)
    Disp_DispMgn_ARBM.append(np.sqrt(DispVecARBM[:,0]**2 + DispVecARBM[:,1]**2 + DispVecARBM[:,2]**2))
    
    #Compute face centroids - after RBM
    # NOTE Points3D_ARBM[image] is a matrix,"data_dict['DIC3DPPresults']['Points3D'][0][0]" is an array, at same shape
    meansRBM = []
    for ifaces in range(facesPy.shape[0]):# in shorted version will be 10, full will be 13368  
        meanOfEachLine = Points3D_ARBM[image][facesPyInt[ifaces,:]-1].mean(axis = 0)
        meansRBM.append(meanOfEachLine)
        FaceCentroids_ARBM[image] = meansRBM
# end of displacements and rigid body motion

# %%
##################################test##################################

# %%
FaceCentroids[1]
stacked = pd.Panel(FaceCentroids.swapaxes(1,2)).to_frame().stack().reset_index()
stacked.columns = ['x', 'y', 'z', 'value']
# save to disk
stacked.to_csv('stacked.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-a04079f68e76> in <module>()
#       1 FaceCentroids[1]
# ----> 2 np.savetxt('FaceCentroids.csv', [FaceCentroids[1]], delimiter=',', fmt='%d')
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# C:\Users\17895\AppData\Roaming\Python\Python37\site-packages\numpy\lib\npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1393         if X.ndim == 0 or X.ndim > 2:
#    1394             raise ValueError(
# -> 1395                 "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1396         elif X.ndim == 1:
#    1397             # Common case -- 1d array of numbers
#
# ValueError: Expected 1D or 2D array, got 3D array instead

# %%
FaceCentroids_ARBM[1]
# Out:
# [array([  2.81926861,  11.41924089, 169.94342866]),
#  array([  5.57064723,  41.17194495, 163.16209536]),
#  array([ 14.80152328,  38.88003582, 176.13848804]),
#  array([ -4.01776834,  12.076862  , 197.7339167 ]),
#  array([ 14.90075082,  40.06087372, 147.01579135]),
#  array([11.76539506, 27.71178033, 64.27765889]),
#  array([ 8.58850874, 43.87951902, 95.42845969]),
#  array([ -4.25442049,  11.74725372, 208.94053753]),
#  array([  3.43524132,   8.21147108, 227.21093579]),
#  array([  3.35416216,  10.25667717, 184.08612903]),
#  array([  0.52935403,  10.18476673, 207.0184561 ]),
#  array([-13.91556553,  15.2753201 , 202.37072415]),
#  array([  8.53093938,  40.24905826, 175.60404994]),
#  array([ -0.34528307,  43.29844054, 128.26768475]),
#  array([ -1.11694255,  10.8577104 , 202.57206296]),
#  array([  1.69002259,  10.03454101, 196.87092028]),
#  array([ -0.30955576,  41.59438736, 167.9345984 ]),
#  array([ 14.93356215,  39.26209135, 165.65625533]),
#  array([  3.0191116 ,  42.37788892, 142.07460179]),
#  array([ 19.28537846,  38.17937122, 162.01574096]),
#  array([-14.62022698,   1.92861603,  45.32952909]),
#  array([-4.2860316 ,  0.42286323, 17.86353894]),
#  array([-6.31680311,  1.66698415,  8.53270576]),
#  array([-9.59801319, -0.37245076, 54.78112636]),
#  array([-13.75227107,   2.72124022,  30.75627465]),
#  array([-2.5770481 , -2.65247958, 55.80510375]),
#  array([ 9.15390479, 45.28155913, 67.47971059]),
#  array([-14.08221781,   0.86444313,  59.44801807]),
#  array([ 7.25018185, 45.47044674, 69.1177694 ]),
#  array([-12.75947598,   2.36393551,  30.76353089]),
#  array([-4.85619094,  1.35895125,  1.76402485]),
#  array([-9.07858736,  0.4628377 , 39.74413678]),
#  array([-8.6888628 , -0.22928495, 47.3845607 ]),
#  array([ 18.411469  ,  38.37178046, 163.78570239]),
#  array([ 6.17502507, 45.27918239, 75.18635722]),
#  array([13.69497378, 44.43481817, 66.83948767]),
#  array([  4.85723295,  41.9369035 , 147.31547197]),
#  array([  4.81360401,  41.82240962, 149.96449311]),
#  array([ 15.77224697,  39.8324591 , 146.9939567 ]),
#  array([ 19.63775708,  40.02669872, 119.07304042]),
#  array([ 16.70656497,  38.89862716, 162.97128633]),
#  array([  3.66052606,  41.40341005, 163.26462576]),
#  array([  8.69624845,  43.31968629, 106.2335728 ]),
#  array([  3.86919955,  41.05364795, 171.50077045]),
#  array([ 11.43159622,  40.20386302, 163.17266534]),
#  array([  2.41518092,   8.22768772, 230.20397597]),
#  array([  1.78299293,  44.37262702, 102.30429336]),
#  array([-6.44493956e-02,  9.62663977e+00,  2.23663924e+02]),
#  array([ 20.73802301,  37.86587366, 158.20233119]),
#  array([ 19.93205381,  37.34120075, 177.65669312]),
#  array([ -2.17613866,  11.64474997, 190.11355426]),
#  array([-10.24676533,  14.48939157, 184.15759581]),
#  array([  2.50998036,   8.81389457, 223.31751131]),
#  array([-8.25226382e-02,  1.01435404e+01,  2.13086660e+02]),
#  array([-5.66110132e-02,  9.89923453e+00,  2.18833538e+02]),
#  array([-14.37352661,  15.10212932, 219.73870203]),
#  array([ -3.08558076,  11.89355031, 193.90102004]),
#  array([ -7.18415136,  12.94695462, 203.20159223]),
#  array([ -1.50835666,  11.8019941 , 183.09851673]),
#  array([-10.72761772,  14.49464781, 195.85622547]),
#  array([-14.72723969,  15.41059207, 213.72430867]),
#  array([ -6.88084585,  12.83825799, 202.56779816]),
#  array([ 17.12884746,  38.2996805 , 174.87056693]),
#  array([ 12.22325812,  39.71456004, 171.01998426]),
#  array([ 14.2477505 ,  40.01874441, 151.69279775]),
#  array([ 16.6639795 ,  39.66702526, 145.22794325]),
#  array([  5.3957211 ,  42.4819673 , 133.48458833]),
#  array([  6.89962292,  41.19576062, 158.1042527 ]),
#  array([ 14.0897822 ,  40.46141712, 142.66524387]),
#  array([ 15.61358983,  39.38877037, 158.35245405]),
#  array([ 12.28076942,  40.77420396, 145.33229808]),
#  array([ 14.07596039,  40.42411541, 143.53951957]),
#  array([ 20.4289502 ,  38.75722661, 140.222778  ]),
#  array([ 19.00654787,  38.27797283, 161.73366087]),
#  array([ 17.62596941,  38.8214778 , 158.57946424]),
#  array([ 18.31048112,  38.08207973, 171.62987732]),
#  array([20.75353239, 42.13929225, 72.56514367]),
#  array([ 20.07202351,  37.74754341, 166.34578485]),
#  array([ 19.33078416,  38.30929545, 158.52997308]),
#  array([ 19.77960012,  40.41072045, 110.38717862]),
#  array([ 16.21389415,  41.02715614, 119.08154329]),
#  array([ 20.46678817,  38.86449292, 137.61343738]),
#  array([ 19.81070031,  40.49334166, 108.65132041]),
#  array([ 19.62400344,  39.13452081, 137.62510652]),
#  array([22.0342142 , 40.56249984, 93.34879694]),
#  array([ 20.97072421,  40.23378223, 106.34202004]),
#  array([20.54468217, 42.41462799, 68.81546421]),
#  array([-3.53446489, -2.28022619, 53.76134281]),
#  array([-5.13774381, -0.30368242, 32.4728582 ]),
#  array([-4.96303585,  1.24505337,  7.8574567 ]),
#  array([-11.84515751,   3.87187531,   6.97922688]),
#  array([-3.78280648, -2.66529368, 61.82026451]),
#  array([-3.14666361, -2.9289523 , 62.49589232]),
#  array([-3.48375034, -2.17922848, 52.79127119]),
#  array([-3.74990065, -2.60885826, 60.82208061]),
#  array([-6.18586777, -0.72246088, 42.74838424]),
#  array([-16.40865386,   2.31933085,  49.67943848]),
#  array([-3.98909311,  0.86938515,  8.85223606]),
#  array([-7.197087  ,  1.57329219, 14.87572394]),
#  array([-7.3541072 ,  1.94759732,  9.52827234]),
#  array([-9.91995814,  1.05733086, 34.73745843]),
#  array([21.40871677, 41.38852592, 82.08824185]),
#  array([ 7.98261012, 44.83641619, 78.77421757]),
#  array([-17.2902371 ,   4.90390433,  19.85941915]),
#  array([-17.20721481,   2.99902032,  42.64911122]),
#  array([14.02671955, 42.83220112, 94.67697176]),
#  array([21.93609447, 41.12689093, 83.53863694]),
#  array([ 17.46110747,  40.9666128 , 113.27937975]),
#  array([ 21.56274329,  40.13986093, 104.32068255]),
#  array([ 15.01597704,  42.07369624, 104.5636359 ]),
#  array([21.66842413, 40.42346422, 98.25318908]),
#  array([  9.47964938,  42.80487571, 114.12800376]),
#  array([ 18.34681901,  40.79564451, 111.54155349]),
#  array([ 16.47097628,  40.86276896, 121.11293375]),
#  array([  2.73246047,  43.37017478, 121.16252986]),
#  array([ 13.569002  ,  40.78307059, 138.59765853]),
#  array([ 10.84895154,  42.13064928, 122.59216663]),
#  array([ 9.78314536, 43.58081264, 97.49859611]),
#  array([ 15.61780458,  41.97658499, 103.40780461]),
#  array([ 6.85450019, 44.49837634, 88.36790977]),
#  array([ 15.5360685 ,  41.76607565, 107.7601762 ]),
#  array([ 3.82434695, 44.42569814, 97.06039775]),
#  array([ 5.33876158, 44.86236368, 85.09257265]),
#  array([11.11763623, 44.47709341, 75.7096321 ]),
#  array([ 8.86137567, 44.56360818, 81.43592882]),
#  array([ 1.04242368, 45.05438852, 89.91536879]),
#  array([10.89838756, 43.92294956, 87.0436846 ]),
#  array([11.17118449, 44.61006928, 73.09954322]),
#  array([13.47559672, 43.88980781, 77.25505865]),
#  array([-12.2081096 ,   1.25539324,  42.68409588]),
#  array([-15.78596116,   1.38072893,  60.77617708]),
#  array([-10.45676351,   2.15379312,  21.78089891]),
#  array([ 0.44205159, 45.25379151, 86.65045841]),
#  array([ 7.1537673 , 45.23808958, 73.48450479]),
#  array([ 1.33309101, 45.75544487, 75.80496414]),
#  array([ 3.36157286, 45.75541055, 72.40087856]),
#  array([ 9.00398108, 44.91646338, 74.45076152]),
#  array([ 4.43391218, 45.10322161, 82.41860024]),
#  array([10.10257868, 44.38656115, 80.90288731]),
#  array([-20.4649104 ,   5.70898315,  26.87210695]),
#  array([-20.53591628,   5.58713608,  28.85003352]),
#  array([-10.24460716,   2.51317987,  16.8478015 ]),
#  array([-20.53184046,   3.53228907,  53.66520745]),
#  array([-21.55454621,   5.92367734,  29.86116319]),
#  array([-14.15916893,   2.72237604,  33.43037787]),
#  array([-17.14357199,   5.14572263,  15.89417456]),
#  array([-16.12751387,   3.48294715,  33.44390179]),
#  array([ 0.47813701, 45.34082751, 84.88450882]),
#  array([11.27830683, 43.23428566, 98.98762477]),
#  array([ 1.16265073, 45.34925338, 83.73841025]),
#  array([11.63889325, 44.15313798, 79.79782098]),
#  array([ 6.11246524, 44.30614381, 93.89959819]),
#  array([ -0.39093188,  41.36326801, 174.15609614]),
#  array([ 0.22912719, 45.55922359, 81.04349344]),
#  array([ -0.23226922,  43.58302237, 122.05858352]),
#  array([  9.16124577,  42.82867269, 114.71048728]),
#  array([  1.74638236,  41.67057179, 161.59980427]),
#  array([  4.7878041 ,  41.75178281, 151.72956264]),
#  array([  7.37268726,  40.67910439, 169.22844188]),
#  array([-14.12056737,  15.68062014, 186.12971701]),
#  array([  0.80259153,  41.85956481, 158.99111019]),
#  array([ 11.40917662,  40.13961707, 164.92665637]),
#  array([  8.29020126,  42.27432189, 129.0442527 ]),
#  array([ 10.50772216,  41.22354385, 143.62692605]),
#  array([  5.86201502,  41.9614108 , 143.75639848]),
#  array([ 10.43981599,  41.04033955, 148.0119009 ]),
#  array([ 10.111863  ,  42.75009039, 112.96461383]),
#  array([  9.36997534,  43.36149192, 103.323721  ]),
#  array([ 13.36686612,  40.23415112, 151.71824553]),
#  array([ 13.14252819,  40.49688112, 147.06034178]),
#  array([  9.35184001,  29.86222089, 179.0532024 ]),
#  array([ -9.13523143,  13.85469525, 197.4413747 ]),
#  array([  6.10299318,  41.72129837, 148.4483025 ]),
#  array([ 10.73804958,  40.96948858, 148.2953315 ]),
#  array([ -1.0261834 ,  41.49332474, 171.83531144]),
#  array([  4.80612341,  40.88051077, 173.20386311]),
#  array([ 17.05352836,  38.08074562, 180.97408289]),
#  array([  1.70584874,  10.69920376, 184.38703794]),
#  array([-1.39335135e-01,  9.09678578e+00,  2.30520109e+02]),
#  array([ -2.30742335,  10.42326689, 223.32476953]),
#  array([-10.92921051,  13.37574499, 226.20761707]),
#  array([-10.03467034,  13.63542615, 210.89046825]),
#  array([ -5.99552341,  13.14912858, 186.29572459]),
#  array([-15.57982032,  16.01362413, 196.03387745]),
#  array([-13.80287971,  14.38707579, 227.17693193]),
#  array([-15.82164167,  15.87285807, 204.33421367]),
#  array([-17.76913044,  16.74376042, 198.64613902]),
#  array([ -3.88141835,  11.29956052, 217.8586896 ]),
#  array([  1.87037858,  41.06778519, 176.94262372]),
#  array([  3.81414699,  40.89393066, 175.91871869]),
#  array([ -0.28751597,  41.6584775 , 166.15620436]),
#  array([-17.93321264,  16.76042109, 192.01484612]),
#  array([ -7.24484215,  13.04881851, 199.36204896]),
#  array([-18.05463967,  16.74190764, 188.21040839]),
#  array([  2.74988707,   8.18777874, 229.54085802]),
#  array([  0.57108397,   9.30961323, 225.2817049 ]),
#  array([ -0.36974595,  10.03542701, 218.51095411]),
#  array([  0.60049708,   9.89059617, 215.6016059 ]),
#  array([ -2.39636544,  11.2677243 , 203.20417525]),
#  array([  1.46246213,  10.04937219, 202.24500894]),
#  array([  3.59387714,   9.35716008, 196.90063472]),
#  array([  2.53123927,   8.97341198, 221.35290025]),
#  array([  3.28558112,   9.4591631 , 197.52411389]),
#  array([ -6.35471976,  13.49835646, 178.40276585]),
#  array([  3.76421402,  10.62498473, 178.59348968]),
#  array([ -3.41518599,  12.63504948, 179.27921131]),
#  array([  2.69466972,   9.71978791, 198.74774624]),
#  array([ -6.97921967,  13.63538164, 181.54476889]),
#  array([  1.68923586,  10.56407811, 186.32144901]),
#  array([ -2.13004646,  11.55602975, 193.90828626]),
#  array([-1.62679744e-01,  1.16545415e+01,  1.79579435e+02]),
#  array([  2.70648137,  10.49721108, 183.43011262]),
#  array([ -4.3728713 ,  12.87705648, 181.1867129 ]),
#  array([  0.45518305,  11.28745657, 182.13234178]),
#  array([ -7.20782087,  13.25932512, 196.45349266]),
#  array([  1.33081668,  10.52820697, 187.92323828]),
#  array([ -4.39279415,  12.57816019, 186.93295275]),
#  array([ -0.22948107,  11.26682343, 185.33459017]),
#  array([-1.93968735e-01,  1.06775726e+01,  1.98728607e+02]),
#  array([ -2.07446376,  11.14702662, 203.52216982]),
#  array([  1.44585178,   9.96588794, 203.21903708]),
#  array([ -0.47798885,  10.65608461, 202.25246104]),
#  array([  3.8266048 ,   9.02297383, 213.00086675]),
#  array([ -2.00562177,  10.87059296, 211.19023256]),
#  array([ -1.35985535,   9.9030103 , 226.24660693]),
#  array([  1.87720774,   9.18624986, 220.73360505]),
#  array([ -1.35826763,   9.95450835, 225.28356234]),
#  array([ -2.29729644,  10.68403316, 218.51039298]),
#  array([ -0.37587232,   9.88149706, 221.39321922]),
#  array([ -4.21840635,  11.20572768, 221.39341891]),
#  array([ -3.43536407,  12.04371394, 191.69444237]),
#  array([ -2.17918193,  11.72725799, 188.20413955]),
#  array([ -3.11190444,  11.9274145 , 192.01049824]),
#  array([-15.6273015 ,  16.00670681, 194.15380153]),
#  array([ -3.03775363,  11.47287709, 203.51893641]),
#  array([ -6.27641936,  12.73462749, 199.34996981]),
#  array([ -1.35728603,  10.78284081, 208.93985271]),
#  array([ -5.94878804,  12.50898383, 201.61112339]),
#  array([ -6.12300798,  11.91117999, 221.3792953 ]),
#  array([ -3.89999512,  11.12162609, 220.75546226]),
#  array([ -8.75467285,  13.26257437, 209.27931056]),
#  array([ -4.01452106,  11.81901188, 202.56874403]),
#  array([ -9.07490836,  13.52234263, 206.08636215]),
#  array([ -5.28653593,  12.24950561, 203.19836918]),
#  array([ -5.03130356,  12.57661505, 192.01919699]),
#  array([ -6.25098709,  12.97751329, 195.48116026]),
#  array([ -5.93281902,  12.74667111, 197.73244583]),
#  array([ -6.91332747,  12.99471396, 198.70743749]),
#  array([ -3.4396963 ,  12.3412323 , 185.00816829]),
#  array([ -3.45277909,  12.17717394, 187.8926334 ]),
#  array([ -4.40721119,  12.7012426 , 184.04927273]),
#  array([ -6.02591598,  13.14202712, 185.34845774]),
#  array([ 15.31198379,  38.52189065, 181.93302378]),
#  array([  1.77832431,  11.07743943, 179.56262045]),
#  array([ -3.09208846,  12.43249735, 181.50610251]),
#  array([ -6.31639034,  13.44277959, 182.1545215 ]),
#  array([ -6.35710621,  13.53134654, 177.45385486]),
#  array([ -6.98268838,  13.59090318, 182.49703302]),
#  array([-12.30078508,  15.10660222, 178.56453088]),
#  array([  2.79906899,  11.03508428, 176.65977208]),
#  array([ -4.3977487 ,  12.44088245, 189.80019685]),
#  array([ -7.21911819,  13.18925204, 197.42434909]),
#  array([ -3.44603505,  12.10040467, 189.80274732]),
#  array([ -4.07825345,  12.27916474, 191.06669607]),
#  array([ -3.11593484,  12.2698804 , 184.3689662 ]),
#  array([ -1.15606495,  11.82085113, 181.50190065]),
#  array([ -2.14653593,  11.9199218 , 185.3214065 ]),
#  array([ -2.15691957,  11.85420824, 186.28502275]),
#  array([ 15.85206412,  39.16716968, 162.12843505]),
#  array([ 16.74307402,  39.00082187, 160.35214869]),
#  array([ 11.46736831,  40.30437739, 160.54148946]),
#  array([ 20.76235768,  37.9342104 , 156.45948747]),
#  array([ 13.07979136,  39.41652687, 173.60035032]),
#  array([ 13.80021959,  39.66058104, 162.78738655]),
#  array([ 11.18867266,  39.5133785 , 181.58236985]),
#  array([ 13.58200892,  39.027844  , 180.27629069]),
#  array([ 16.26593598,  38.5392196 , 174.90776024]),
#  array([ 12.18394888,  39.59548212, 174.51816283]),
#  array([ 12.75390699,  39.39842975, 175.94701235]),
#  array([ 13.99090453,  39.29207512, 170.93906047]),
#  array([ 11.25132573,  39.68632666, 177.19437451]),
#  array([  6.33032709,  40.51787995, 177.21348498]),
#  array([ 19.38837252,  38.47325948, 154.17197438]),
#  array([ 11.66716963,  40.85778513, 146.51570304]),
#  array([  3.91714164,  41.18806992, 167.96319816]),
#  array([  6.46699152,  40.90873487, 166.63933024]),
#  array([  7.73907055,  41.68834966, 143.70327514]),
#  array([ 14.14662969,  40.61380082, 139.16824111]),
#  array([ 14.11700946,  40.53521654, 140.91654132]),
#  array([ 12.78060281,  41.2526827 , 132.48923308]),
#  array([ 12.37580598,  41.03125535, 139.2040334 ]),
#  array([ 13.66420613,  41.04054958, 132.47798028]),
#  array([ 13.9071734 ,  41.68872781, 117.63084522]),
#  array([  6.52569434,  42.82962276, 122.90900595]),
#  array([ 13.59124966,  41.69988027, 119.08576244]),
#  array([ 21.6482437 ,  39.52535728, 115.88773827]),
#  array([ 12.76683297,  42.06832599, 115.59551235]),
#  array([ 11.34587419,  42.5777798 , 111.51341318]),
#  array([ 14.48975804,  40.6774166 , 135.96071566]),
#  array([  7.90916644,  42.13907802, 133.1481512 ]),
#  array([ 15.89209729,  40.15964087, 139.13551164]),
#  array([ 14.18799157,  40.72565386, 136.54743483]),
#  array([ 19.80539773,  39.62698442, 126.3159838 ]),
#  array([ 16.35623635,  40.55568649, 128.08455099]),
#  array([ 15.57657906,  41.02264297, 122.85875698]),
#  array([ 17.8407318 ,  40.28247439, 125.17060537]),
#  array([  7.37122862,  42.45393683, 128.17679311]),
#  array([ 17.36128524,  40.69755468, 119.36979498]),
#  array([ 19.70753879,  40.21699374, 114.72980801]),
#  array([ 19.59539147,  39.91252478, 121.68090177]),
#  array([ 18.06370563,  40.03160584, 128.93900684]),
#  array([ 18.90246805,  39.73868688, 129.80142405]),
#  array([ 17.6033482 ,  39.63960601, 139.97771741]),
#  array([ 17.32114877,  38.85016007, 160.04267042]),
#  array([ 19.36698326,  38.41060735, 155.9139999 ]),
#  array([ 16.23117269,  40.21810558, 135.93363333]),
#  array([ 16.79799542,  40.03374566, 136.50533521]),
#  array([ 15.75884879,  38.90301055, 169.11674144]),
#  array([ 12.89831477,  39.81505068, 164.57137671]),
#  array([ 17.14052908,  38.3323922 , 173.99850777]),
#  array([ 14.52593447,  38.99912868, 174.98744967]),
#  array([  2.48397796,  11.45192986, 170.59460325]),
#  array([ 17.89316534,  37.77700204, 182.6749592 ]),
#  array([ 20.06116696,  37.71611632, 167.21556828]),
#  array([ 19.69761043,  37.5660292 , 173.89631364]),
#  array([ 16.29850833,  38.63372271, 172.29141338]),
#  array([ 15.79288373,  39.00036851, 166.49622579]),
#  array([ 17.5319807 ,  38.55584491, 165.55865834]),
#  array([ 18.85105065,  37.83053831, 173.92847329]),
#  array([ 20.46466719,  37.0773425 , 179.95561373]),
#  array([ 16.07011343,  39.77824104, 146.4051267 ]),
#  array([ 20.47502287,  37.10762331, 179.08600453]),
#  array([ 19.96338655,  37.43310985, 175.04662898]),
#  array([ 19.52149037,  38.84821842, 144.58950173]),
#  array([ 15.08874909,  39.69814371, 154.29052645]),
#  array([ 11.65283266,  40.81982002, 147.39254555]),
#  array([ 20.57894749,  39.16824184, 130.65495666]),
#  array([ 21.57820025,  39.33425198, 120.22520703]),
#  array([14.13744193, 43.11885253, 88.58344419]),
#  array([21.82145569, 40.8288094 , 89.59389665]),
#  array([20.06955153, 41.17940992, 93.90341265]),
#  array([ 19.30270617,  40.81778908, 105.46543135]),
#  array([20.32799439, 41.03192005, 95.06300836]),
#  array([ 18.06722443,  40.89322842, 111.25126877]),
#  array([ 14.93308126,  41.86158031, 108.91790143]),
#  array([20.03639027, 41.09341704, 95.63755842]),
#  array([17.53351141, 41.99098133, 92.99803331]),
#  array([19.3695195 , 41.82201705, 86.09139046]),
#  array([16.07040283, 43.14492061, 79.07567761]),
#  array([20.4392312 , 41.32303661, 88.99665394]),
#  array([19.40230396, 41.90664565, 84.35900241]),
#  array([19.25623818, 41.52751992, 92.15719443]),
#  array([13.46602894, 43.0435949 , 93.21406332]),
#  array([21.28359025, 41.88243716, 74.01854841]),
#  array([20.49510159, 42.28611802, 71.40619514]),
#  array([19.60071932, 42.420934  , 73.97666239]),
#  array([18.22695303, 42.96093138, 71.6281993 ]),
#  array([18.83548365, 42.89482486, 69.62855831]),
#  array([-10.05330287,  -0.42394706,  60.53255923]),
#  array([15.44404495, 43.98986514, 66.91061496]),
#  array([19.6681941 , 42.59539002, 70.51822121]),
#  array([18.33110926, 43.22645077, 66.4401501 ]),
#  array([17.81128949, 42.70864152, 78.25650787]),
#  array([20.70086476, 42.00412188, 75.15708955]),
#  array([21.11942734, 41.4535773 , 82.66013557]),
#  array([16.13753822, 43.31675214, 75.60687508]),
#  array([21.0367929 , 41.23941637, 86.9859487 ]),
#  array([20.48993426, 41.45366522, 86.40009839]),
#  array([22.09859988, 41.55349705, 74.89910634]),
#  array([22.01669411, 41.33881538, 79.21635023]),
#  array([21.4400448 , 41.4713046 , 80.35883922]),
#  array([-2.11269389, -3.19917364, 61.4886282 ]),
#  array([-2.84108964, -2.44752924, 53.43766719]),
#  array([-8.78055376, -0.97587546, 61.86788182]),
#  array([-9.05821124, -0.77334984, 60.52775831]),
#  array([-6.38600187, -1.04433148, 48.75904092]),
#  array([-2.55085162, -1.965162  , 45.44964925]),
#  array([-1.33681493, -1.94226061, 39.4518066 ]),
#  array([-0.80624726, -0.96230474, 24.74118759]),
#  array([-8.31356188,  2.35609551,  8.54139184]),
#  array([ 1.92026980e-03, -5.29359623e-01,  6.71188428e+00]),
#  array([-5.62268743,  0.22560447, 26.84740182]),
#  array([-3.02405612,  0.48252378,  9.84872618]),
#  array([-0.36975623, -0.44729026,  9.44010529]),
#  array([-4.99395098,  1.2004628 ,  8.86170178]),
#  array([-4.26178582,  1.06601034,  6.50763352]),
#  array([-2.95017882,  0.57936319,  6.81947969]),
#  array([-3.19736192,  0.79224229,  2.43403967]),
#  array([-6.42595097,  0.85278291, 20.8144773 ]),
#  array([-9.30152424,  2.07483621, 17.83274226]),
#  array([-4.61528263, -0.08940897, 26.86167959]),
#  array([-9.72351153,  2.04005583, 20.47490015]),
#  array([-4.81041212,  0.22476936, 22.503546  ]),
#  array([-3.03510587, -0.75961242, 30.5574433 ]),
#  array([-0.92585539, -1.21443485, 28.60495743]),
#  array([-7.06175983, -0.18658183, 38.7466891 ]),
#  array([-1.43546401, -2.10941046, 42.4342876 ]),
#  array([-4.62825622, -1.44942998, 46.4248846 ]),
#  array([-3.32611788, -1.93105602, 47.77187419]),
#  array([-7.23580214, -0.47756743, 43.72959165]),
#  array([-4.16618355, -1.34658254, 42.76510752]),
#  array([-5.74204434, -1.30150762, 49.43048836]),
#  array([-3.89608117, -2.21659985, 54.43139605]),
#  array([-7.93199455,  0.35966223, 34.74476949]),
#  array([-3.37715747, -1.35583361, 39.45593969]),
#  array([-9.80830629, -0.09262919, 50.37113654]),
#  array([-7.59128297, -1.03733561, 54.78229761]),
#  array([-8.84669108,  0.84429581, 32.76155294]),
#  array([-3.67778631, -0.52061207, 28.85761636]),
#  array([-4.45819806,  0.14272292, 21.83632858]),
#  array([-7.46984341,  1.11476851, 21.79726846]),
#  array([-12.91681894,   2.10076098,  35.74323176]),
#  array([-5.97305771, -0.36810982, 35.76929603]),
#  array([-4.88258052,  1.35767407,  4.84162514]),
#  array([-6.3512503 ,  1.6139091 ,  9.53044327]),
#  array([-7.14228893,  2.26644096,  2.53219904]),
#  array([-10.77882013,   3.6016987 ,   3.93131816]),
#  array([-6.17650412,  1.26232084, 13.86743498]),
#  array([-8.61634451,  1.88197736, 17.51432407]),
#  array([-6.49741519,  1.39378344, 13.53400447]),
#  array([-2.47117706,  0.08914461, 12.51771871]),
#  array([-8.3690006 ,  1.61731544, 19.8108953 ]),
#  array([-9.33199048,  2.02290404, 18.82341408]),
#  array([-7.7842504 ,  1.25813446, 21.46580171]),
#  array([-11.37446747,   2.64570948,  19.81771145]),
#  array([-9.52566318,  2.37981036, 15.54859345]),
#  array([-9.25947254,  2.14854377, 16.8516592 ]),
#  array([-9.12150406,  2.99608691,  2.56243423]),
#  array([-11.87945746,   2.47228067,  24.43842925]),
#  array([-6.58429543,  0.61815779, 25.84001426]),
#  array([-9.25601873,  2.80152419,  7.57590884]),
#  array([-7.40369758,  1.8792942 , 11.54276678]),
#  array([-10.76836453,   2.30634908,  21.45578   ]),
#  array([-6.89950235,  0.75419563, 25.49704277]),
#  array([-6.65963603,  0.49064435, 27.82063086]),
#  array([-6.92712966,  0.03519543, 34.7570055 ]),
#  array([-12.61632112,   1.24164076,  45.34188826]),
#  array([-14.34745923,   2.39748432,  38.38148376]),
#  array([-12.40167941,   1.60783679,  39.37252205]),
#  array([-7.4826081 , -0.21172205, 41.42024915]),
#  array([-12.7305732 ,   1.04459932,  48.32485027]),
#  array([-11.24174172,   0.85512704,  43.68683106]),
#  array([-9.60964528, -0.38397226, 55.79945734]),
#  array([-5.21523897, -2.38218099, 64.5127584 ]),
#  array([13.85247735, 44.02646256, 73.21368432]),
#  array([10.9328114 , 44.82404938, 70.18737134]),
#  array([12.95189134, 44.19362205, 74.04863225]),
#  array([21.2312154 , 41.74735358, 76.60835681]),
#  array([15.58669194, 43.54237674, 74.14310005]),
#  array([20.47822662, 42.2425047 , 72.2697493 ]),
#  array([14.94850433, 44.3533082 , 62.8446164 ]),
#  array([-12.70600523,   0.48290703,  58.80167586]),
#  array([-6.93372033, -1.27299705, 55.45580533]),
#  array([-2.91150965, -2.55611873, 55.45418055]),
#  array([-8.62027284, -0.73378442, 56.81505899]),
#  array([-4.90648696, -1.90117048, 54.43838499]),
#  array([-3.9429217 , -2.92776091, 65.83790777]),
#  array([-12.73845338,   0.43440773,  59.813938  ]),
#  array([16.45582336, 43.31364869, 74.17173178]),
#  array([20.29554606, 41.76777996, 81.77887365]),
#  array([-7.12765709, -1.56373747, 62.52543703]),
#  array([ 0.28674419, 13.64528709, 64.24885927]),
#  array([11.04840354, 44.30330325, 79.19433438]),
#  array([19.82548601, 42.18606337, 76.86561552]),
#  array([17.04962448, 42.38590743, 88.06797262]),
#  array([13.73038376, 43.71912553, 79.29230397]),
#  array([ 19.24151668,  40.65620514, 108.93828235]),
#  array([ 13.80290983,  42.25506111, 106.87687524]),
#  array([11.66745369, 43.4013842 , 94.04686313]),
#  array([14.47134387, 43.15334221, 86.26949066]),
#  array([11.69867679, 43.4818817 , 92.30193192]),
#  array([12.77152815, 43.74429153, 82.74093979]),
#  array([  6.46790632,  43.52931489, 108.54558966]),
#  array([ 15.88687023,  41.84553496, 104.57188159]),
#  array([11.62240345, 43.28371624, 96.66514109]),
#  array([15.20357597, 42.56199851, 94.1172209 ]),
#  array([13.16056693, 43.08599135, 93.78850786]),
#  array([16.31752004, 42.96202676, 81.10598941]),
#  array([14.39221093, 43.76572073, 75.54968031]),
#  array([11.03043837, 44.258643  , 80.06582512]),
#  array([ 11.47712253,  42.91174009, 104.52396323]),
#  array([ 13.77006405,  42.17095642, 108.62063255]),
#  array([10.40149388, 43.48962802, 97.22177897]),
#  array([ 9.84923859, 43.74813116, 94.00318421]),
#  array([ 12.81052674,  42.18419917, 112.97676197]),
#  array([  9.22349142,  42.98884568, 111.20681033]),
#  array([13.37115301, 42.79869553, 98.44322309]),
#  array([21.10678342, 40.59719394, 98.53722296]),
#  array([ 11.16586741,  42.9459551 , 105.10251913]),
#  array([ 2.20283081, 44.57757619, 97.31007458]),
#  array([ 11.00556284,  42.53573919, 113.84371122]),
#  array([  8.21667739,  42.93394623, 115.58444498]),
#  array([ 10.36154303,  42.55435349, 115.8816366 ]),
#  array([ 14.73032313,  41.32154759, 121.11871785]),
#  array([  8.23423101,  42.97775744, 114.70778432]),
#  array([  6.37462543,  43.29009663, 113.82055001]),
#  array([  7.63750099,  43.13774863, 113.2422265 ]),
#  array([ 11.44393705,  42.8275145 , 106.27138197]),
#  array([  0.63144011,  44.03901322, 111.13123047]),
#  array([  4.08833656,  44.24857802, 100.00244504]),
#  array([ 6.69653911, 44.1070828 , 96.25638943]),
#  array([13.12973361, 43.00617998, 95.53117698]),
#  array([  8.265111  ,  43.0576337 , 112.95319318]),
#  array([  5.50554451,  43.61503567, 109.41514323]),
#  array([ 9.63289346, 44.02781021, 89.33306873]),
#  array([ 3.34778532, 44.90818708, 88.53336418]),
#  array([ 9.02667428, 44.15497292, 88.73145133]),
#  array([ 6.14968695, 44.39689826, 92.14585302]),
#  array([ 7.21380316, 44.56835678, 86.04248589]),
#  array([ 6.39380441, 45.00102192, 79.87307718]),
#  array([10.65056799, 44.1207111 , 84.12593631]),
#  array([ 4.47028159, 45.19180608, 80.66277527]),
#  array([10.22568904, 44.6933035 , 74.79877696]),
#  array([ 5.13254908, 45.17583244, 79.52213252]),
#  array([ 6.0461946 , 44.13937732, 97.41117528]),
#  array([ 6.73039295, 44.19182407, 94.50203981]),
#  array([10.38479365, 43.44756673, 98.095118  ]),
#  array([ 9.46439608, 43.60370506, 98.07443005]),
#  array([13.49751394, 43.12523187, 91.47168283]),
#  array([12.53286126, 43.12972826, 95.81011491]),
#  array([14.42497   , 43.03274298, 88.88042278]),
#  array([14.96471425, 42.77247821, 91.21323416]),
#  array([ 9.02260513, 44.96184753, 73.57812817]),
#  array([14.69615858, 43.72216154, 74.9809632 ]),
#  array([10.30011696, 44.87571695, 71.31616717]),
#  array([10.43205013, 45.19723806, 65.22758669]),
#  array([ 8.43240504, 45.13098062, 72.09307963]),
#  array([ 6.61674448, 45.54305011, 69.37286638]),
#  array([-14.49321372,   2.14511154,  41.34172959]),
#  array([-14.7985405 ,   3.00255869,  32.76789725]),
#  array([-12.00494025,   1.60350807,  37.72468678]),
#  array([-14.17746656,   2.69148731,  34.4300825 ]),
#  array([-12.53628125,   1.37693591,  42.3439469 ]),
#  array([-15.56635111,   2.37237597,  43.32982272]),
#  array([-13.07854927,   2.50135013,  30.42703478]),
#  array([-10.09452232,   1.44414573,  30.44278806]),
#  array([-16.17010631,   4.73951086,  15.8698252 ]),
#  array([-9.65883893,  2.14806925, 18.49066284]),
#  array([-14.52028438,   3.44758249,  24.77805582]),
#  array([-11.04355682,   1.8758935 ,  29.45713302]),
#  array([-17.6486581 ,   4.31021506,  29.78683642]),
#  array([-12.61774579,   2.59264297,  26.77357235]),
#  array([-14.96242569,   3.38678855,  28.43425569]),
#  array([-16.54963894,   4.11070295,  26.78850758]),
#  array([-17.05494045,   3.95538928,  31.44696287]),
#  array([-17.53198707,   4.50241942,  26.80792654]),
#  array([-16.1193878 ,   4.82564368,  14.89129219]),
#  array([-10.39429864,   2.9444087 ,  12.59255203]),
#  array([-9.85285862,  3.14205352,  5.92338199]),
#  array([-17.80236282,   6.73211709,   3.82898713]),
#  array([-17.46296956,   4.61580853,  24.81889853]),
#  array([-11.44230222,   2.52236535,  21.78242091]),
#  array([-16.21988003,   4.65235009,  16.84410329]),
#  array([-12.49299408,   3.46659437,  15.54588584]),
#  array([-19.50554603,   3.88579817,  43.32095559]),
#  array([-14.2712658 ,   1.84007429,  44.6663489 ]),
#  array([-17.29804096,   2.85178304,  46.66883605]),
#  array([-15.24641239,   2.23371492,  43.66506456]),
#  array([-18.584705  ,   3.40117501,  46.3390773 ]),
#  array([-14.21495223,   2.62624866,  35.41884911]),
#  array([-11.54359205,   0.38209383,  52.73861484]),
#  array([ 7.70738171, 45.7742476 , 62.44829085]),
#  array([-17.61186396,   2.35909153,  55.7296877 ]),
#  array([-1.18408733e+01, -6.22547082e-02,  6.38617104e+01]),
#  array([-18.50189981,   2.87428584,  52.68173043]),
#  array([-13.7844008 ,   0.69760888,  60.80152117]),
#  array([-19.62264912,   3.69742626,  48.3509046 ]),
#  array([-13.7984732 ,   1.29150229,  50.34613077]),
#  array([-20.21991957,   4.04766002,  46.67934935]),
#  array([-18.44428522,   3.6401863 ,  41.34408809]),
#  array([-22.772556  ,   6.60547738,  27.56990254]),
#  array([-17.95658435,   4.47263813,  29.46344258]),
#  array([-19.71812229,   5.59880428,  24.55069099]),
#  array([-16.93336873,   4.149335  ,  28.4553488 ]),
#  array([-22.7010213 ,   6.03067745,  35.83353536]),
#  array([-20.75994514,   5.20152259,  35.79520495]),
#  array([-17.73343018,   4.8472928 ,  23.5187813 ]),
#  array([-10.72843086,   2.37748825,  20.47466023]),
#  array([-20.56389885,   6.22090742,  20.59971807]),
#  array([-12.32100027,   3.08045674,  18.82777562]),
#  array([-16.06535391,   5.5819866 ,   6.69201567]),
#  array([-18.85548746,   6.99119675,   4.77734822]),
#  array([-19.41926747,   6.08300306,  15.59494295]),
#  array([-21.65093629,   7.74862261,   9.08041371]),
#  array([-18.67642627,   6.61985843,   7.04304957]),
#  array([-15.75683062,   5.42392844,   7.01714288]),
#  array([-20.6410656 ,   5.41619924,  31.83869321]),
#  array([-22.37124141,   6.59661231,  25.9204966 ]),
#  array([-23.50308982,   6.75020716,  29.91065242]),
#  array([-24.36477257,   7.3545052 ,  26.9656322 ]),
#  array([-22.12043801,   7.65187176,  11.70215338]),
#  array([-21.2577709 ,   6.42998381,  22.96862958]),
#  array([-25.97990409,   7.3631886 ,  35.56133473]),
#  array([-24.98936585,   6.97085712,  35.53982299]),
#  array([-19.40294458,   3.3887041 ,  50.6737644 ]),
#  array([-21.15369869,   4.5172296 ,  43.66245051]),
#  array([-25.83512847,   5.49495308,  56.32375945]),
#  array([-25.66499328,   5.80582174,  52.38378186]),
#  array([-21.47672923,   4.65514858,  43.32848889]),
#  array([ 4.83332494, 46.06133023, 64.01051485]),
#  array([ 7.26834078, 45.51472122, 68.24439356]),
#  array([ 1.27282494, 45.6146258 , 78.44853528]),
#  array([ 3.11863608, 45.17120581, 83.82678748]),
#  array([ 3.29739208, 44.78274331, 91.17372747]),
#  array([ 5.32031345, 44.81749274, 85.97029599]),
#  array([ 2.53677132, 45.39573443, 80.57063794]),
#  array([ 4.13761107, 45.19801712, 81.23307572]),
#  array([-23.08068833,   4.01454721,  61.36020953]),
#  array([-18.90424158,   2.88340354,  54.35631588]),
#  array([ 6.53778371, 45.354205  , 72.86859765]),
#  array([ 6.51926383, 45.30909068, 73.74386648]),
#  array([ 3.89280234, 46.2165697 , 63.06940224]),
#  array([-15.0476981 ,   1.2638393 ,  58.43209554]),
#  array([ 5.29976614, 45.58098526, 71.63284192]),
#  array([ 7.40849315, 45.04940448, 76.4153297 ]),
#  array([ 3.562774  , 45.43249892, 77.9799418 ]),
#  array([ 5.44462112, 45.12258658, 79.82966107]),
#  array([ 2.27364636, 45.57568692, 77.61995258]),
#  array([ 3.5451951 , 45.38933678, 78.85947396]),
#  array([ 4.90635855, 44.61750598, 90.93504908]),
#  array([ 2.40981522, 45.08839692, 86.73379993]),
#  array([ 8.04775603, 44.17560265, 91.3271842 ]),
#  array([ 4.95613522, 44.74216498, 88.30037186]),
#  array([  9.38561374,  43.40181994, 102.44822707]),
#  array([  8.42331102,  43.46240981, 104.18374978]),
#  array([ 5.89263131, 44.58354599, 89.21228887]),
#  array([ 6.13054926, 44.35061165, 93.02285669]),
#  array([ 4.76701036, 44.27275869, 97.96539546]),
#  array([ 1.2742426 , 44.79247237, 94.63349021]),
#  array([ -0.47340576,  43.83018224, 117.3292431 ]),
#  array([  7.29983668,  43.11748882, 114.70437617]),
#  array([ 1.22335609, 44.66579901, 97.28250577]),
#  array([ 0.86675825, 44.62332016, 98.74551893]),
#  array([  0.56725289,  43.87770422, 114.67306655]),
#  array([  7.33120421,  43.1980364 , 112.94777357]),
#  array([ 0.15342254, 45.38000449, 84.5746155 ]),
#  array([  0.61548816,  43.99878283, 112.01642287]),
#  array([  1.67937861,  44.11706132, 107.60517281]),
#  array([  3.03907296,  44.14297046, 104.3873637 ]),
#  array([ 1.00497013, 44.96412621, 91.68016272]),
#  array([ -0.14686644,  43.79345953, 117.62498312]),
#  array([  1.80710961,  43.58730276, 118.51137148]),
#  array([  3.3516417,  42.3700493, 141.4751926]),
#  array([  0.31905313,  42.37733177, 147.77759134]),
#  array([  1.06474337,  42.55713729, 142.13434115]),
#  array([  0.353868  ,  43.34380312, 126.19108117]),
#  array([ -0.26261234,  41.72730641, 164.37729249]),
#  array([  3.05111157,  41.5659125 , 160.93955725]),
#  array([-1.06788851e-01,  4.12017710e+01,  1.77981175e+02]),
#  array([  0.71469344,  41.61730019, 165.20525587]),
#  array([  1.31893736,  42.33414707, 146.85240814]),
#  array([  2.96158548,  42.22702253, 145.61333977]),
#  array([  2.36622751,  42.42881476, 142.38937601]),
#  array([  0.52120034,  42.90526542, 135.34932522]),
#  array([ -1.07561848,  42.29468905, 151.97945655]),
#  array([  1.05078353,  42.52016102, 143.02084702]),
#  array([  3.1647571 ,  42.75779276, 133.23164191]),
#  array([  8.18837001,  42.00670898, 135.19327816]),
#  array([  4.97031532,  41.34459181, 160.84053006]),
#  array([  4.61891808,  41.29145135, 163.21232961]),
#  array([  4.4802984 ,  40.89726805, 173.81344059]),
#  array([  1.60451276,  41.27011095, 172.24062448]),
#  array([  5.72692743,  41.59748677, 152.57360218]),
#  array([  8.57472428,  41.28786047, 149.82801066]),
#  array([  2.85011972,  41.93031239, 152.69355404]),
#  array([  2.91993734,  42.115871  , 148.26876323]),
#  array([  0.55329892,  42.98606132, 133.57552785]),
#  array([  6.43212293,  42.5891011 , 128.18759414]),
#  array([  1.19990134,  42.90564995, 134.15355283]),
#  array([  3.25705763,  42.99456601, 127.93077576]),
#  array([  7.48068424,  42.73542286, 122.02398833]),
#  array([  4.15861158,  42.72968344, 131.44806035]),
#  array([  8.09310157,  42.61525837, 122.60622988]),
#  array([  4.25041746,  42.96619788, 126.15502623]),
#  array([  4.64517482,  43.11973916, 122.03853866]),
#  array([  4.75641054,  43.40239035, 115.86787844]),
#  array([  6.54179547,  42.87067628, 122.02910918]),
#  array([  6.50987651,  42.78915112, 123.78796492]),
#  array([  4.33913192,  42.33194087, 139.68189922]),
#  array([ 11.43978449,  41.11605334, 141.85153995]),
#  array([  6.12927863,  41.79266575, 146.68569955]),
#  array([ 10.78017255,  41.08201651, 145.66384159]),
#  array([ 10.26721314,  42.31112085, 121.13542718]),
#  array([ 14.34153206,  41.13837401, 126.93886559]),
#  array([  5.66208162,  43.16346661, 118.5115926 ]),
#  array([ 13.01231095,  41.86746011, 118.50489107]),
#  array([  9.98475111,  42.42275983, 119.96881525]),
#  array([ 13.56227511,  41.62280807, 120.83165673]),
#  array([ 12.85202225,  41.44299856, 128.11514304]),
#  array([ 13.67814109,  41.07793133, 131.60383002]),
#  array([ 11.64091013,  40.78623931, 148.26860754]),
#  array([  8.90339873,  41.29383016, 148.35329856]),
#  array([  9.18586071,  42.04437311, 130.78766695]),
#  array([ 11.84766979,  41.34234294, 135.12823754]),
#  array([  7.72535817,  41.65174686, 144.58287589]),
#  array([  6.81800219,  41.86639814, 142.84840671]),
#  array([  7.97625979,  41.44387772, 148.38368408]),
#  array([  9.83990226,  41.1766062 , 147.44527219]),
#  array([ 11.15951979,  40.34476487, 161.13792628]),
#  array([  6.7085579 ,  41.57282523, 149.89371684]),
#  array([ 11.12350345,  40.24376673, 163.77078398]),
#  array([ 14.04806504,  39.45515988, 166.56616199]),
#  array([  9.60019098,  40.51556665, 164.1335449 ]),
#  array([  7.50307035,  41.04667747, 159.54439168]),
#  array([ 10.34481866,  39.86324866, 177.24808873]),
#  array([ 13.53507811,  38.89507478, 183.77712329]),
#  array([  7.30253202,  40.47992924, 174.50969915]),
#  array([  9.16390058,  40.19408642, 174.39394828]),
#  array([  7.4785205 ,  40.97812373, 161.30593706]),
#  array([  3.77807335,  41.72256485, 155.30482559]),
#  array([ 12.40767907,  40.23914703, 157.0038458 ]),
#  array([  5.61939722,  41.30794185, 159.63277005]),
#  array([  4.65651391,  41.39514691, 160.56212513]),
#  array([  1.11355526,  41.78572228, 160.156889  ]),
#  array([  5.71877311,  40.65571871, 175.78746127]),
#  array([  7.5541746 ,  40.26169047, 179.18450809]),
#  array([ 11.95367294,  39.85941679, 168.98983591]),
#  array([  4.81604322,  40.91056792, 172.32195408]),
#  array([ -9.97691527,  14.45369971, 179.75052046]),
#  array([  8.50405937,  40.17661679, 177.36427838]),
#  array([ -7.91717823,  13.63622896, 190.12447064]),
#  array([ -5.34445416,  12.67164172, 192.65098918]),
#  array([-12.9725394 ,  15.41627267, 175.07937871]),
#  array([ -7.01290373,  13.67015465, 178.72967398]),
#  array([-10.90957371,  14.72109664, 182.60136557]),
#  array([ -9.38677325,  14.34524093, 174.68933199]),
#  array([  6.28719201,  40.39268302, 180.73989804]),
#  array([  9.12465955,  40.08713639, 177.0319447 ]),
#  array([  6.26309321,  40.32538148, 182.50431204]),
#  array([  9.98548163,  39.76392858, 181.36570136]),
#  array([-10.37527641,  14.65608529, 173.76087931]),
#  array([  0.34768367,  31.88965611, 180.70092023]),
#  array([ -7.33069776,  13.54012957, 185.05642807]),
#  array([ -4.39779991,  12.40124936, 190.75100811]),
#  array([ -2.94545653,  22.80309982, 176.8051125 ]),
#  array([  8.42841826,  39.95687543, 183.52012008]),
#  array([ -7.96696081,  13.90068483, 181.57628567]),
#  array([-13.30101855,  15.44021191, 176.68911274]),
#  array([-11.68068047,  14.57578833, 200.71631348]),
#  array([ -7.15995883,  12.89478866, 205.11170123]),
#  array([ -7.19996905,  13.32528147, 195.48206173]),
#  array([ -4.99332134,  12.56947995, 193.89758779]),
#  array([ -3.23749334,  11.09867366, 217.53826736]),
#  array([ -4.85591409,  11.42291312, 221.70623316]),
#  array([ -2.91299639,  11.02377747, 216.90075269]),
#  array([-10.66564991,  13.81613758, 212.17117156]),
#  array([ -7.7928831 ,  13.15956494, 204.47206132]),
#  array([-11.60007166,  14.15719461, 213.12135811]),
#  array([-15.32801383,  15.52888757, 217.84824824]),
#  array([-14.40653878,  15.28216965, 214.04087448]),
#  array([-10.99290007,  13.97453087, 210.90065482]),
#  array([-10.63218523,  13.77666306, 214.08040604]),
#  array([-11.74945062,  14.82991949, 193.04913479]),
#  array([-12.10302826,  14.97143455, 190.84787749]),
#  array([-10.96312322,  13.22271964, 228.15840606]),
#  array([-10.92301726,  13.43491451, 225.23833987]),
#  array([-11.63227619,  14.37218696, 207.37763546]),
#  array([-13.60397179,  15.42757684, 196.89025524]),
#  array([ -9.93494918,  13.5328073 , 216.59397621]),
#  array([-18.21722699,  16.62339846, 216.89638652]),
#  array([-14.80240344,  14.56046626, 229.16230866]),
#  array([-15.35357657,  15.22984577, 223.61377709]),
#  array([-15.42125803,  15.72704412, 209.31956296]),
#  array([-13.42249152,  14.77489902, 218.79144635]),
#  array([-14.46940422,  15.41369871, 208.35391469]),
#  array([ -9.07554274,  13.34262778, 209.92254309]),
#  array([-13.83477568,  15.05009434, 210.92179222]),
#  array([-12.499724  ,  14.51586468, 215.00808299]),
#  array([-12.80265492,  15.25022681, 187.36582421]),
#  array([ -9.27425622,  14.21962268, 183.1915508 ]),
#  array([-13.26804081,  15.37742266, 179.54699746]),
#  array([-11.96685088,  15.00981773, 178.87058815]),
#  array([  4.70521878,  40.59049717, 181.14974932]),
#  array([  3.50895334,  40.97365797, 174.76243056]),
#  array([-15.52565206,  15.88602877, 200.81090538]),
#  array([-11.94746021,  14.50661948, 207.05997974]),
#  array([  6.25237618,  40.2940675 , 183.38570685]),
#  array([-10.31054208,  14.55013988, 179.44413228]),
#  array([-17.23961166,  16.6020795 , 176.79510523]),
#  array([-13.14735699,  15.41297438, 185.14978582]),
#  array([ -8.734843  ,  24.3005074 , 175.18571328]),
#  array([-14.2706225 ,  15.83523745, 174.79057961]),
#  array([  4.69427423,  40.55883555, 182.03259818]),
#  array([-18.8810006 ,  17.19582844, 173.37204638]),
#  array([-12.97565814,  15.366344  , 176.04355088]),
#  array([  0.99381523,  41.44923284, 169.03206247]),
#  array([-17.51977981,  16.60997708, 196.13666532]),
#  array([-15.97000162,  16.14064858, 192.88682854]),
#  array([-13.71923768,  15.47207704, 191.21411096]),
#  array([-14.69542585,  15.76702384, 191.25215789]),
#  array([-18.72420296,  16.96989429, 200.63160137]),
#  array([-15.54655969,  16.04173916, 196.95764957]),
#  array([-12.78678127,  14.51329002, 219.42165618]),
#  array([-17.23251768,  16.09331215, 221.67399059]),
#  array([-16.44766549,  15.03946044, 229.55245472]),
#  array([-16.60145864,  15.86494561, 221.34629065]),
#  array([-17.47981236,  15.20352038, 230.61040419]),
#  array([-5.87621952e-02,  9.79839170e+00,  2.20755996e+02]),
#  array([  2.83909335,   9.36032754, 211.13282078]),
#  array([ -1.03588192,   9.83107842, 225.60423341]),
#  array([  1.86570272,   9.26425532, 218.81836558]),
#  array([  3.77504549,   8.35015015, 223.63544338]),
#  array([  1.53450453,   9.03964479, 224.3166313 ]),
#  array([  2.63771151,   7.76750989, 232.59835633]),
#  array([ -1.17260016,   9.17032525, 232.53871898]),
#  array([  1.86917127,   9.56958833, 213.0499596 ]),
#  array([  3.47209094,   8.73242884, 219.42189269]),
#  array([  3.49580731,   9.07483381, 213.64693868]),
#  array([  2.52035556,   9.44529074, 211.76008677]),
#  array([  3.50324802,   9.04669072, 214.59139517]),
#  array([  2.51182348,   9.38493157, 212.71876039]),
#  array([  2.50551356,   9.48391865, 209.89034153]),
#  array([  1.86951615,   9.62033269, 212.0884769 ]),
#  array([  0.86264875,  10.08006745, 207.33851652]),
#  array([-7.72564026e-02,  1.02451483e+01,  2.11169299e+02]),
#  array([  1.4507136 ,   9.93382453, 204.16655158]),
#  array([  3.4108967 ,   9.2847808 , 206.05163934]),
#  array([  2.45658021,   9.55283383, 207.0210293 ]),
#  array([  1.85701714,   9.67041652, 210.20755953]),
#  array([  2.75568992,   9.49948734, 205.42117745]),
#  array([  0.82197665,  10.11982343, 205.41897472]),
#  array([  3.6824119 ,   9.20126403, 202.64782583]),
#  array([  2.43002283,   9.73615372, 202.25312981]),
#  array([  3.49017072,   9.1089148 , 212.69788143]),
#  array([  2.8347138 ,   9.26889136, 213.0351332 ]),
#  array([  3.45361477,   9.23861045, 207.98347018]),
#  array([  1.87002974,   9.6615042 , 211.13923721]),
#  array([  3.80867236,   9.09341582, 210.19095163]),
#  array([  3.69832868,   9.34458324, 200.70018296]),
#  array([  2.73123046,   9.52644587, 203.54821117]),
#  array([  2.59792136,  10.04004847, 188.28480649]),
#  array([  3.66580705,   9.35794618, 199.72575959]),
#  array([ -1.441265  ,  10.97737522, 202.25017651]),
#  array([  1.62566784,  10.31152441, 189.21411014]),
#  array([  3.5589042 ,   9.70242641, 188.31859009]),
#  array([  3.31512666,  10.07380584, 186.03440912]),
#  array([  1.76284475,  10.99933459, 180.52811676]),
#  array([  3.81761672,  11.14474474, 170.88497504]),
#  array([  2.47408947,  11.14541476, 176.34022234]),
#  array([  3.37121294,  10.34093196, 183.11638733]),
#  array([  3.41830459,  10.64249292, 179.24451844]),
#  array([  2.71185489,  10.55714867, 182.46773521]),
#  array([  0.43708382,  11.21089733, 183.09317005]),
#  array([  2.7940899 ,  10.97436973, 177.62203756]),
#  array([  3.78837665,  10.78950446, 176.64597943]),
#  array([ 20.44453224,  37.01758109, 181.69454157]),
#  array([ 17.92175989,  37.86448382, 180.06304875]),
#  array([  1.82156131,  11.54121243, 171.88690677]),
#  array([ -4.11479356,  13.00697468, 172.95941158]),
#  array([  2.39319063,  10.6870045 , 182.13805282]),
#  array([  3.74559382,  10.53150606, 179.5691165 ]),
#  array([ -1.1442917 ,  11.88130939, 180.54828698]),
#  array([  2.73349304,  10.70113818, 180.53522432]),
#  array([  3.55738291,   9.65296789, 189.27569011]),
#  array([ -1.22250136,  11.39881336, 188.20662475]),
#  array([  3.59161878,   9.80300502, 187.35725844]),
#  array([  3.28991393,   9.97060058, 187.01300679]),
#  array([  2.59127421,   9.82145613, 192.14005694]),
#  array([ -0.27002711,  10.97116632, 190.12697456]),
#  array([  2.25977318,  10.04369888, 189.87474085]),
#  array([  0.69116749,  10.53716727, 192.07228512]),
#  array([  1.64260841,  10.38870159, 188.25049156]),
#  array([  0.68260013,  10.57431234, 191.11078402]),
#  array([ -0.53501553,  10.85741565, 196.5008114 ]),
#  array([  2.74323235,   9.69465474, 200.66377527]),
#  array([  1.69832979,  10.01151759, 197.81379519]),
#  array([ -1.45993211,  10.99914345, 201.2900093 ]),
#  array([ -0.58189352,  11.19639452, 187.89426278]),
#  array([  1.62500878,  10.26457586, 190.1706697 ]),
#  array([  0.73641413,  10.4962569 , 194.90369736]),
#  array([  2.63319428,   9.79149968, 194.95142414]),
#  array([  0.36608121,  10.7089532 , 190.78159922]),
#  array([  0.72631587,  10.51674091, 193.96038165]),
#  array([  0.77276121,  11.16354699, 182.45169091]),
#  array([ -0.21597716,  11.34078327, 184.36816011]),
#  array([  0.49255499,  11.49442345, 179.24855756]),
#  array([  0.82729789,  11.68531628, 173.81818294]),
#  array([  0.49698374,  11.78309027, 173.50504751]),
#  array([ -3.46403466,  12.87587318, 171.67550854]),
#  array([  1.39689069,  10.84620121, 184.055342  ]),
#  array([ -1.51532549,  11.65619979, 185.96791372]),
#  array([ -0.54266636,  11.40422066, 185.00799967]),
#  array([ -1.18686039,  11.68235124, 183.41811508]),
#  array([ -0.53732812,  11.50179522, 183.09697492]),
#  array([ -1.49366718,  11.87017868, 182.14018061]),
#  array([ -0.50380657,  12.14409808, 170.66485968]),
#  array([  2.806301  ,  11.15062396, 174.73616206]),
#  array([ 12.97535389,  28.92611221, 178.00962741]),
#  array([ 13.88323627,  38.97795389, 179.67749833]),
#  array([ -2.11326376,  12.18426932, 180.55014923]),
#  array([ -2.43493033,  12.34924875, 179.27362179]),
#  array([ 18.18474932,  37.71325488, 182.08108959]),
#  array([ -1.47621178,  12.34338723, 172.58169067]),
#  array([ -4.40120369,  12.47116877, 188.85456683]),
#  array([ -1.22968777,  11.34354059, 189.16275452]),
#  array([ -1.54475394,  11.4308112 , 189.79658021]),
#  array([  0.38484238,  10.64075513, 192.69996271]),
#  array([ -1.20620312,  11.2928435 , 191.06862671]),
#  array([ -1.17438993,  11.21687935, 193.92046888]),
#  array([  0.50844748,  10.20809375, 206.05318316]),
#  array([ -3.93315004,  11.46079827, 212.16782654]),
#  array([ -1.16400765,  11.14590599, 195.82827069]),
#  array([ -0.21338136,  10.79155995, 195.85229814]),
#  array([ -3.29241634,  11.41966848, 208.93912968]),
#  array([ -0.39950713,  10.4041034 , 209.90263546]),
#  array([  0.90489587,   9.83055558, 214.01763166]),
#  array([ -4.89964622,  11.69314689, 214.08685947]),
#  array([-8.10730725e-02,  1.01941946e+01,  2.12126241e+02]),
#  array([ -1.03614181,  10.65912315, 209.26063127]),
#  array([ -1.06361718,  10.71712014, 207.3401307 ]),
#  array([  1.55143988,   9.74249013, 211.77327954]),
#  array([ -2.05922872,  11.08768406, 205.4233008 ]),
#  array([ -0.47152397,  10.61477988, 203.21560067]),
#  array([ -0.40308056,  10.49867523, 207.97810551]),
#  array([  1.84857118,   9.74304789, 208.30478055]),
#  array([ -0.40124453,  10.35651019, 210.85901236]),
#  array([  1.52386468,   9.86133767, 207.98194743]),
#  array([  0.92994469,   9.78579909, 215.91301524]),
#  array([  2.86525492,   9.1335312 , 216.84803565]),
#  array([ -1.04494384,  10.4151028 , 214.05063089]),
#  array([  1.87130363,   9.52919727, 214.00180656]),
#  array([ -1.35300789,  10.51484753, 214.68231303]),
#  array([-3.61989162e-02,  9.98459026e+00,  2.17860819e+02]),
#  array([ -0.99593821,  10.31358786, 217.85888195]),
#  array([  2.51767028,   9.09454837, 218.48213872]),
#  array([  1.88421426,   9.15043862, 221.68903226]),
#  array([  2.82462166,   8.67635388, 223.64652612]),
#  array([  0.86678984,   9.04314815, 227.53965109]),
#  array([ -0.512061  ,   9.0014178 , 232.20321247]),
#  array([ -6.15894046,  11.54706687, 227.19592232]),
#  array([ -3.34264505,  10.24422122, 230.1679837 ]),
#  array([  2.81802697,   8.54785028, 225.59770302]),
#  array([  2.79339656,   8.40006757, 227.54142715]),
#  array([  2.32601528,   7.91558802, 232.26032499]),
#  array([ -0.38182111,   9.91498454, 220.44187594]),
#  array([-6.93614652e-02,  9.51189936e+00,  2.25601636e+02]),
#  array([ -1.95136207,  10.69605609, 216.89955458]),
#  array([ -1.00346618,  10.39655335, 215.9425038 ]),
#  array([ -1.31479524,  10.48799382, 216.57944654]),
#  array([ -1.32950711,  10.50992195, 215.6275322 ]),
#  array([ -1.12070637,   9.32705103, 231.5184278 ]),
#  array([ -2.141284  ,   9.49929655, 232.53126913]),
#  array([-9.41467555e-02,  9.36868716e+00,  2.27542150e+02]),
#  array([ -3.39499723,  10.03326788, 232.16111257]),
#  array([ -9.99964874,  12.87948986, 228.15595557]),
#  array([ -2.07681189,   9.73977879, 230.51971556]),
#  array([ -6.2324108 ,  11.26176602, 230.15281456]),
#  array([ -4.86316403,  11.20955277, 225.57075535]),
#  array([ -3.9588983,  10.555582 , 229.4929103]),
#  array([ -3.90294561,  11.06936645, 221.7173797 ]),
#  array([ -0.40845294,   9.5070477 , 227.2152986 ]),
#  array([ -2.016122  ,  10.03057986, 227.54003982]),
#  array([ -2.3919308 ,   9.8820181 , 230.18746824]),
#  array([ -1.02414214,  10.163322  , 219.80103612]),
#  array([ -1.99076205,  10.28409627, 223.65611763]),
#  array([ -1.05081462,  10.49242093, 212.14469071]),
#  array([ -2.96984237,  11.29701026, 209.25964315]),
#  array([ -3.30509571,  11.45110234, 207.97707843]),
#  array([ -1.37174318,  10.81019508, 207.98033852]),
#  array([ -2.27260512,  10.8175866 , 216.58324323]),
#  array([ -3.26873982,  10.95011081, 219.4752718 ]),
#  array([ -2.94459002,  11.05311652, 215.01132358]),
#  array([ -2.32614406,  11.09860234, 208.93932737]),
#  array([ -4.89141786,  11.9017275 , 210.2330618 ]),
#  array([ -6.18411579,  12.4900802 , 207.02789476]),
#  array([ -3.93334826,  11.62253924, 209.26033706]),
#  array([ -4.30203284,  11.86831889, 205.1035078 ]),
#  array([ -3.34205347,  11.53801696, 205.10283988]),
#  array([ -6.2565404 ,  12.60689538, 202.25024089]),
#  array([ -3.94189469,  11.65894861, 208.29897164]),
#  array([ -2.33655031,  11.132436  , 207.97834884]),
#  array([ -3.9792169 ,  11.74601025, 205.4235087 ]),
#  array([ -2.02630948,  11.04285078, 207.33648814]),
#  array([ -2.96155182,  11.06649838, 214.06593645]),
#  array([ -5.15705272,  11.72499474, 218.49361067]),
#  array([ -2.30846756,  10.56243355, 220.44627866]),
#  array([ -6.74987232,  12.19569655, 220.72529544]),
#  array([ -3.26648688,  10.90070665, 220.44235219]),
#  array([ -3.2971742 ,  10.44271001, 228.18218392]),
#  array([ -3.27723969,  10.5874335 , 226.22705139]),
#  array([ -2.33320982,  10.16632683, 227.21301271]),
#  array([ -2.94641554,  10.77036321, 220.7671459 ]),
#  array([ -1.0208133 ,  10.02401806, 222.68188214]),
#  array([ -6.12752143,  11.85116609, 222.34987361]),
#  array([ -3.92586976,  10.72608924, 227.52370847]),
#  array([ -4.21916133,  11.30594431, 219.46333197]),
#  array([ -6.1024781 ,  12.12426314, 217.53848453]),
#  array([ -4.85171088,  11.53016498, 219.77525258]),
#  array([-10.03514904,  13.58421221, 211.85772876]),
#  array([ -4.87016825,  11.14607709, 226.54190378]),
#  array([ -7.06364309,  12.33657628, 220.3998532 ]),
#  array([ -4.85578758,  11.37051658, 222.67430016]),
#  array([ -6.13959876,  11.72725667, 224.29195253]),
#  array([ -5.25901788,  10.94053713, 230.14828609]),
#  array([ -8.21424003,  11.79580005, 231.15903611]),
#  array([ -5.28669635,  10.83260676, 231.14650656]),
#  array([ -5.80862028,  11.71990813, 222.67163866]),
#  array([ -7.0686877 ,  12.27517156, 221.37157718]),
#  array([-10.94282551,  13.3045442 , 227.18114512]),
#  array([ -3.26636671,  10.6576313 , 225.25418621]),
#  ...]

# %%
test = [None]*5
test[1] = [None]*10
test[1][1] = [0]*3
test
# Out:
# [None,
#  [None, [0, 0, 0], None, None, None, None, None, None, None, None],
#  None,
#  None,
#  None]

# %%
#########################################################################
#############################draft#############################

# %%
# look at sturcture of Cmat
print(len(DIC3D['Deform']['Cmat']),type(DIC3D['Deform']['Cmat']))
print(len(DIC3D['Deform']['Cmat'][1]),type(DIC3D['Deform']['Cmat'][1]))
print(len(DIC3D['Deform']['Cmat'][1][0]),type(DIC3D['Deform']['Cmat'][1][0]),DIC3D['Deform']['Cmat'][1][0].shape)
DIC3D['Deform']['Cmat'][1][0]
# Out:
# 5 <class 'list'>
# 1 <class 'list'>
# 3 <class 'numpy.ndarray'> (3, 3, 13368)
# array([[[ 9.54706166e-01,  9.99721181e-01,  9.99791127e-01, ...,
#           9.61583530e-01,  9.64104144e-01,  9.29239937e-01],
#         [ 1.25426801e-02,  4.98027651e-05,  6.45146625e-05, ...,
#           2.45581977e-02,  2.29515234e-02,  4.21250553e-02],
#         [-4.23826665e-02, -5.61566929e-05,  6.04123520e-05, ...,
#          -9.38330928e-02, -6.44587177e-02, -5.24051118e-02]],
#
#        [[ 1.25426801e-02,  4.98027651e-05,  6.45146625e-05, ...,
#           2.45581977e-02,  2.29515234e-02,  4.21250553e-02],
#         [ 9.96375337e-01,  9.99991099e-01,  9.99980063e-01, ...,
#           9.84930135e-01,  9.86086963e-01,  9.73878446e-01],
#         [ 9.77107333e-03,  8.55981086e-06, -2.11028149e-05, ...,
#           5.00918586e-02,  3.27467305e-02,  3.80296299e-02]],
#
#        [[-4.23826665e-02, -5.61566929e-05,  6.04123520e-05, ...,
#          -9.38330928e-02, -6.44587177e-02, -5.24051118e-02],
#         [ 9.77107333e-03,  8.55981086e-06, -2.11028149e-05, ...,
#           5.00918586e-02,  3.27467305e-02,  3.80296299e-02],
#         [ 9.34820799e-01,  9.99598985e-01,  9.99402435e-01, ...,
#           9.26315389e-01,  9.78348713e-01,  9.16464885e-01]]])

# %%
#Compute rigid body transformation between point clouds
#error message: matrix A is not 3xN, it is 6978x3
[RotMat,TransVec] = rigid_transform_3D(
                    data_dict['DIC3DPPresults']['Points3D'][1][0],
                    data_dict['DIC3DPPresults']['Points3D'][0][0])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-ec974186df03> in <module>()
#       3 [RotMat,TransVec] = rigid_transform_3D(
#       4                     data_dict['DIC3DPPresults']['Points3D'][1][0],
# ----> 5                     data_dict['DIC3DPPresults']['Points3D'][0][0])
#
# D:\OneDrive - The University of Western Australia\Git\3D-DIC\Step4\rigid_transform_3D.py in rigid_transform_3D(A, B)
#      16
#      17     if num_rows != 3:
# ---> 18         raise Exception("matrix A is not 3xN, it is {}x{}".format(num_rows, num_cols))
#      19
#      20     [num_rows, num_cols] = B.shape;
#
# Exception: matrix A is not 3xN, it is 6978x3

# %%
#change row & column
#delete nan before transpose
argA = data_dict['DIC3DPPresults']['Points3D'][2][0]
nanIndex = np.argwhere(np.isnan(argA))[:,0]
#argA = np.delete(argA, nanIndex,0)
argA = argA.transpose()
argB = data_dict['DIC3DPPresults']['Points3D'][0][0]
nanIndex = np.argwhere(np.isnan(argB))[:,0]
#argB = np.delete(argB, nanIndex,0)
argB = argB.transpose()
print("shape of a is:",argA.shape, "b:",argB.shape)
print(type(argA))
argBm = np.asmatrix(argB)
print(type(argBm))
# Out:
# shape of a is: (3, 6978) b: (3, 6978)
# <class 'numpy.ndarray'>
# <class 'numpy.matrix'>

# %%
x = data_dict['DIC3DPPresults']['Points3D'][0][0]
nanIndex =  (np.isnan(x))[:,0]
x[nanIndex]
# Out:
# array([], shape=(0, 3), dtype=float64)

# %%
# nan check
x =data_dict['DIC3DPPresults']['Points3D'][4][0]
nanIndex = np.argwhere(np.isnan(x))[:,0]
x1 = np.delete(x, nanIndex,0)
x1[np.argwhere(np.isnan(x1))[:,0]]
# Out:
# array([], shape=(0, 3), dtype=float64)

# %%
# try run rigid_t here------------------------
# find mean column wise
centroid_A = np.mean(argA, axis=1)#
centroid_B = np.mean(argBm, axis=1)#array([[  0.64130487], [ 25.41937206], [119.06233202]]) 3*1 shape

# %%
print("shape of a is:",centroid_A.shape, "b:",centroid_B.shape)
print(centroid_A)
print(centroid_B)
# Out:
# shape of a is: (3,) b: (3, 1)
# [  0.64130487  25.41937206 119.06233202]
# [[  0.64130487]
#  [ 25.41937206]
#  [119.06233202]]

# %%
# ensure centroids are 3x1 (necessary when A or B are
# numpy arrays instead of numpy matrices)
centroid_A = centroid_A.reshape(-1, 1) # to 3*1 shape
centroid_B = centroid_B.reshape(-1, 1)

# %%
num_rows, num_cols = argA.shape;
# subtract mean
Am = argA - np.tile(centroid_A, (1, num_cols))
Bm = argB - np.tile(centroid_B, (1, num_cols))

# %%
H = np.dot(Am,np.transpose(Bm))

# %%
# find rotation
U, S, Vt = np.linalg.svd(H)
R = Vt.T * U.T

# %%
t = -R*centroid_A + centroid_B

# %%
R
# Out:
# matrix([[ 0.99888906, -0.0450026 , -0.0139792 ],
#         [ 0.04441871,  0.99822806, -0.03959452],
#         [ 0.01573628,  0.03892959,  0.99911804]])

# %%
Vt
#rigid_t ends here---------------------------------
# Out:
# matrix([[-0.04064423, -0.06882704, -0.99680032],
#         [-0.54752799, -0.83296977,  0.07984016],
#         [-0.8357997 ,  0.54902112, -0.00382932]])

# %%
RotMat,TransVec = rigid_transform_3D(argA,argBm)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-91-edd136d6bc8e> in <module>()
# ----> 1 RotMat,TransVec = rigid_transform_3D(argA,argBm)
#
# D:\OneDrive - The University of Western Australia\Git\3D-DIC\Step4\rigid_transform_3D.py in rigid_transform_3D(A, B)
#      43
#      44     # find rotation
# ---> 45     U, S, Vt = linalg.svd(H)
#      46     R = Vt.T * U.T
#      47
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# C:\Users\17895\AppData\Roaming\Python\Python37\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1624
#    1625         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1626         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1627         u = u.astype(result_t, copy=False)
#    1628         s = s.astype(_realType(result_t), copy=False)
#
# C:\Users\17895\AppData\Roaming\Python\Python37\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#     104
#     105 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 106     raise LinAlgError("SVD did not converge")
#     107
#     108 def _raise_linalgerror_lstsq(err, flag):
#
# LinAlgError: SVD did not converge

# %%
print(RotMat)
print(TransVec)
# Out:
# [[ 1.00000000e+00  7.12971599e-17 -8.10578730e-17]
#  [-6.38875587e-17  1.00000000e+00  3.43774206e-16]
#  [-5.50102670e-17  6.17902485e-17  1.00000000e+00]]
# [[ 7.99360578e-15]
#  [-3.55271368e-14]
#  [-2.84217094e-14]]

# %%
#Compute displacements between frames (per point)
DispVec = data_dict['DIC3DPPresults']['Points3D'][1][0] - data_dict['DIC3DPPresults']['Points3D'][0][0]

# %%
# this produce same error
# done debugging
def testfunction(A,B):
    #if len(A) == len(B):
        #print("wellllll")
   # else:
       # print("wrong")
    print(A.shape)
    print(len(B))
testfunction(argA,argB)
# Out:
# (3, 6978)
# 3

# %%
np.sqrt(DispVec[:,0]**2 + DispVec[:,1]**2 + DispVec[:,2]**2)[0:10]
# Out:
# array([21.12711363, 21.12998768, 21.18308559, 21.30089595, 21.31974562,
#        21.27991817, 21.33715132, 21.30546194, 21.24607238, 21.31043549])

# %%
#compute face centroids
facesPyInt.shape
facesPyInt[1,:]
# Out:
# array([4958, 4957, 4689])

# %%
data_dict['DIC3DPPresults']['Points3D'][1][0][facesPyInt[1,:]-1]# frist 1: image, second 1: face(to 13368)
# Out:
# array([[  8.87010205,  47.95226179, 163.64820456],
#        [  8.87154231,  47.95528282, 164.5318443 ],
#        [  9.80990601,  47.78336433, 163.59180251]])

# %%
meanOfEachLine = data_dict['DIC3DPPresults']['Points3D'][1][0][facesPyInt[1,:]-1].mean(axis = 0) 
meanOfEachLine
# Out:
# array([  9.18385012,  47.89696964, 163.92395046])

# %%
#read coorComb
DIC3D['corrComb'][0][0][facesPyInt-1] #DIC3D.corrComb{ii}(F); in this case we have 10 instances
# Out:
# array([[1.35222278, 1.36593578, 1.29955775],
#        [0.16628634, 0.16344256, 0.19751639],
#        [0.16086167, 0.13946344, 0.13863298],
#        [1.25526403, 1.25750794, 1.28705816],
#        [0.15405274, 0.17574434, 0.1730297 ],
#        [0.06320487, 1.52480727, 0.0826026 ],
#        [0.21619105, 0.21821001, 0.21504012],
#        [1.27900074, 1.26905087, 1.28909456],
#        [1.49670128, 1.46146731, 1.46961375],
#        [1.27959089, 1.23319027, 1.24494115]])

# %%
x = np.amax(DIC3D['corrComb'][1][0][facesPyInt],1) # find max in each row
x
# Out:
# array([1.10297569, 0.20416364, 0.16270319, 1.30087252, 0.18329407,
#        1.27172527, 0.22074969, 1.27464799, 1.41727779, 1.29572459])

# %%
facesPy
# Out:
# array([[ 610.,  338.,  339.],
#        [4958., 4957., 4689.],
#        [2248., 1977., 1978.],
#        [2210., 2211., 2480.],
#        [2011., 2282., 2281.],
#        [1021., 1022., 1293.],
#        [4496., 4228., 4497.],
#        [2469., 2468., 2199.],
#        [   7.,  279.,  278.],
#        [ 323.,   52.,  324.]])
